# %% [markdown]
# <a href="https://colab.research.google.com/github/bhumi-1830/data_science_lab/blob/main/SimpleOperations4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check if a number is a palindrome
def is_palindrome_number(n):
    # Convert the number to a string
    num_str = str(n)
    # Compare the string with its reverse
    if num_str == num_str[::-1]:
        return f"{n} is a palindrome number."
    else:
        return f"{n} is not a palindrome number."

# Example usage:
num1 = 121
print(is_palindrome_number(num1))

num2 = 123
print(is_palindrome_number(num2))

num3 = 7
print(is_palindrome_number(num3))

num4 = 1221
print(is_palindrome_number(num4))
# Out:
# 121 is a palindrome number.
# 123 is not a palindrome number.
# 7 is a palindrome number.
# 1221 is a palindrome number.
